# %% [markdown]
# # Update Paths in train.txt / val.txt
#
# 將 `train.txt` 和 `val.txt` 裡的路徑前綴換成 server 上的路徑。

# %%
from pathlib import Path


version = "v3_2_1_correction"  # ← 改這裡
task = "label-data"  # ← 改這裡（od 或 seg)


# ── 設定 ──────────────────────────────────────────────────
# 要取代的舊路徑前綴（本機）
OLD_PREFIX = f"/Users/tony.tu/Desktop/戴承智慧/polyp/yolo_data/od/"


# 換成的新路徑前綴（server 上的路徑）
NEW_PREFIX = f"/root/Desktop/endo-semi/data/label-data/"   # ← 改這裡

# 要處理的 txt 檔案（可以加更多）
TXT_FILES = [
    Path(f"label-data/{version}/train.txt"),
    Path(f"label-data/{version}/val.txt"),
]

# 預覽模式
DRY_RUN = True

# %%
# 預覽
for txt_file in TXT_FILES:
    if not txt_file.exists():
        print(f"[SKIP] 找不到：{txt_file}")
        continue
    lines = txt_file.read_text().strip().splitlines()
    print(f"\n{txt_file}  ({len(lines)} 筆)")
    print(f"  舊：{lines[0]}")
    print(f"  新：{lines[0].replace(OLD_PREFIX, NEW_PREFIX, 1)}")
# Out:
# label-data/v3_2_1_correction/train.txt  (16275 筆)
#   舊：/Users/tony.tu/Desktop/戴承智慧/polyp/yolo_data/od/v3_2_1_correction/images/R0001_001009.jpg
#   新：/root/Desktop/endo-semi/data/label-data/v3_2_1_correction/images/R0001_001009.jpg
#
# label-data/v3_2_1_correction/val.txt  (4347 筆)
#   舊：/Users/tony.tu/Desktop/戴承智慧/polyp/yolo_data/od/v3_2_1_correction/images/R0026_015181.jpg
#   新：/root/Desktop/endo-semi/data/label-data/v3_2_1_correction/images/R0026_015181.jpg

# %%
DRY_RUN = False  # 確認後改為 False

if DRY_RUN:
    print("DRY RUN，不會修改任何檔案")
else:
    for txt_file in TXT_FILES:
        if not txt_file.exists():
            print(f"[SKIP] 找不到：{txt_file}")
            continue
        content = txt_file.read_text()
        new_content = content.replace(OLD_PREFIX, NEW_PREFIX)
        txt_file.write_text(new_content)
        n = content.count(OLD_PREFIX)
        print(f"{txt_file}: 取代 {n} 筆")
    print("完成")
# Out:
# label-data/v3_2_1_correction/train.txt: 取代 16275 筆
# label-data/v3_2_1_correction/val.txt: 取代 4347 筆
# 完成
